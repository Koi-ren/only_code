# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/ws/HD_Rotem2_pycode/Day09/7024_Seoul_Tem.csv', encoding = 'cp949')
df.head(3)
# Out:
#     지점 지점명       일시  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  최저기온(°C)
# 0  108  서울  1970-01      -4.8         0.0        -8.8       8.9     -20.2
# 1  108  서울  1970-02      -0.2         4.7        -3.9      12.0     -10.8
# 2  108  서울  1970-03       0.4         4.8        -3.2      16.0      -7.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지점          660 non-null    int64
#  1   지점명         660 non-null    object
#  2   일시          660 non-null    object
#  3   평균기온(°C)    660 non-null    float64
#  4   평균최고기온(°C)  660 non-null    float64
#  5   평균최저기온(°C)  660 non-null    float64
#  6   최고기온(°C)    660 non-null    float64
#  7   최저기온(°C)    660 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 41.4+ KB

# %%
plt.rcParams['font.family'] = 'gulim'

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.title('서울시 기온변화')
plt.plot(range(1,len(df)+1), df['최고기온(°C)'], label='최고기온(°C)', c='r') 
plt.xlabel('월')
plt.ylabel('기온')
plt.legend()
plt.show()

# %%
df['일시'] = pd.to_datetime(df['일시'], format='%Y-%m')
df['일시']
# Out:
# 0     1970-01-01
# 1     1970-02-01
# 2     1970-03-01
# 3     1970-04-01
# 4     1970-05-01
#          ...
# 655   2024-08-01
# 656   2024-09-01
# 657   2024-10-01
# 658   2024-11-01
# 659   2024-12-01
# Name: 일시, Length: 660, dtype: datetime64[ns]

# %%
df3 = df.set_index('일시')

# %%
df3.head(100)
# Out:
#              지점 지점명  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  최저기온(°C)
# 일시
# 1970-01-01  108  서울      -4.8         0.0        -8.8       8.9     -20.2
# 1970-02-01  108  서울      -0.2         4.7        -3.9      12.0     -10.8
# 1970-03-01  108  서울       0.4         4.8        -3.2      16.0      -7.3
# 1970-04-01  108  서울      12.2        18.3         7.1      26.0       0.8
# 1970-05-01  108  서울      18.7        24.6        13.8      29.8      10.0
# ...         ...  ..       ...         ...         ...       ...       ...
# 1977-12-01  108  서울       2.4         6.3        -0.9      13.7      -9.4
# 1978-01-01  108  서울      -2.4         1.7        -6.0       7.4     -13.3
# 1978-02-01  108  서울      -2.5         2.0        -6.2      11.0     -16.0
# 1978-03-01  108  서울       4.2         9.2        -0.2      17.4      -8.2
# 1978-04-01  108  서울      11.5        17.2         6.6      25.0       0.4
#
# [100 rows x 7 columns]

# %%
df_Sum = df3[pd.DatetimeIndex(df3.index).month == 9]

# %%
df_Sum.head(9)
# Out:
#              지점 지점명  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  최저기온(°C)
# 일시
# 1970-09-01  108  서울      21.2        26.0        17.5      31.2       7.9
# 1971-09-01  108  서울      20.6        25.2        16.8      29.6       9.7
# 1972-09-01  108  서울      19.0        24.0        14.8      27.2       9.5
# 1973-09-01  108  서울      20.3        25.0        16.5      28.6       8.3
# 1974-09-01  108  서울      20.6        25.8        16.5      29.9      11.2
# 1975-09-01  108  서울      22.6        27.1        19.0      31.5      13.6
# 1976-09-01  108  서울      19.9        25.3        15.4      30.2      11.0
# 1977-09-01  108  서울      21.5        26.7        17.4      31.1       8.8
# 1978-09-01  108  서울      20.9        25.8        17.1      30.6      13.4

# %%
plt.title('서울시 70~24년 여름철 기온 변화')
plt.plot(range(1, len(df_Sum['최고기온(°C)']) + 1), df_Sum['최고기온(°C)'], label='최고기온', c='r')

plt.xlabel('8월')
plt.ylabel('기온')
plt.xlim(0,70)
plt.ylim(0, 40)
plt.legend()
plt.rcParams['figure.figsize'] = (200, 500)

plt.show()
plt.savefig('서울.png')

# %%
df_Sum_6 = df3[pd.DatetimeIndex(df3.index).month == 6]
df_Sum_7 = df3[pd.DatetimeIndex(df3.index).month == 7]
df_Sum_8 = df3[pd.DatetimeIndex(df3.index).month == 8]
df_Sum_9 = df3[pd.DatetimeIndex(df3.index).month == 9]
df_Sum_10 = df3[pd.DatetimeIndex(df3.index).month == 10]

# %%
plt.title('서울시 70~24년 여름철 기온 변화')
plt.plot(range(1, len(df_Sum_6['최고기온(°C)']) + 1), df_Sum_6['최고기온(°C)'], label='6월 최고기온', c='c')
plt.plot(range(1, len(df_Sum_7['최고기온(°C)']) + 1), df_Sum_7['최고기온(°C)'], label='7월 최고기온', c='m')
plt.plot(range(1, len(df_Sum_8['최고기온(°C)']) + 1), df_Sum_8['최고기온(°C)'], label='8월 최고기온', c='r')
plt.plot(range(1, len(df_Sum_9['최고기온(°C)']) + 1), df_Sum_9['최고기온(°C)'], label='9월 최고기온', c='g')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()
plt.rcParams['figure.figsize'] = (9, 7)

plt.show()

# %%
plt.title('서울시 70~24년 여름철 기온 변화')
plt.plot(range(1, len(df_Sum_6['평균최고기온(°C)']) + 1), df_Sum_6['평균최고기온(°C)'], label='6월 평균최고기온', c='c')
plt.plot(range(1, len(df_Sum_7['평균최고기온(°C)']) + 1), df_Sum_7['평균최고기온(°C)'], label='7월 평균최고기온', c='m')
plt.plot(range(1, len(df_Sum_8['평균최고기온(°C)']) + 1), df_Sum_8['평균최고기온(°C)'], label='8월 평균최고기온', c='r')
plt.plot(range(1, len(df_Sum_9['평균최고기온(°C)']) + 1), df_Sum_9['평균최고기온(°C)'], label='9월 평균최고기온', c='g')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()
plt.rcParams['figure.figsize'] = (9, 7)

plt.show()

# %%
plt.subplot(1, 2, 1)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.plot(range(1, len(df_Sum_6['평균최고기온(°C)']) + 1), df_Sum_6['평균최고기온(°C)'], label='6월 평균최고기온', c='c')
plt.plot(range(1, len(df_Sum_7['평균최고기온(°C)']) + 1), df_Sum_7['평균최고기온(°C)'], label='7월 평균최고기온', c='m')
plt.plot(range(1, len(df_Sum_8['평균최고기온(°C)']) + 1), df_Sum_8['평균최고기온(°C)'], label='8월 평균최고기온', c='r')
plt.plot(range(1, len(df_Sum_9['평균최고기온(°C)']) + 1), df_Sum_9['평균최고기온(°C)'], label='9월 평균최고기온', c='g')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()

plt.subplot(1, 2, 2)
plt.title('서울시 70~24년 여름철 최고기온 변화')
plt.plot(range(1, len(df_Sum_6['최고기온(°C)']) + 1), df_Sum_6['최고기온(°C)'], label='6월 최고기온', c='c')
plt.plot(range(1, len(df_Sum_7['최고기온(°C)']) + 1), df_Sum_7['최고기온(°C)'], label='7월 최고기온', c='m')
plt.plot(range(1, len(df_Sum_8['최고기온(°C)']) + 1), df_Sum_8['최고기온(°C)'], label='8월 최고기온', c='r')
plt.plot(range(1, len(df_Sum_9['최고기온(°C)']) + 1), df_Sum_9['최고기온(°C)'], label='9월 최고기온', c='g')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()
plt.rcParams['figure.figsize'] = (9, 100)
plt.show()

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (15, 7)

plt.subplot(1, 2, 1)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.boxplot([df_Sum_6['평균최고기온(°C)'], df_Sum_7['평균최고기온(°C)'], df_Sum_8['평균최고기온(°C)'], df_Sum_9['평균최고기온(°C)']], tick_labels=['6월', '7월', '8월', '9월'], patch_artist=True, boxprops=dict(facecolor='c'))
plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.ylim(10, 50)

plt.subplot(1, 2, 2)
plt.title('서울시 70~24년 여름철 최고기온 변화')
plt.boxplot([df_Sum_6['최고기온(°C)'], df_Sum_7['최고기온(°C)'], df_Sum_8['최고기온(°C)'], df_Sum_9['최고기온(°C)']], tick_labels=['6월', '7월', '8월', '9월'], patch_artist=True, boxprops=dict(facecolor='m'))
plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.ylim(10, 50)

plt.tight_layout()
plt.show()

# %%
plt.subplot(2, 2, 1)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.plot(range(1, len(df_Sum_6['평균최고기온(°C)']) + 1), df_Sum_6['평균최고기온(°C)'], label='6월 평균최고기온', c='c')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()

plt.subplot(2, 2, 2)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.plot(range(1, len(df_Sum_7['평균최고기온(°C)']) + 1), df_Sum_7['평균최고기온(°C)'], label='7월 평균최고기온', c='r')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()

plt.subplot(2, 2, 3)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.plot(range(1, len(df_Sum_8['평균최고기온(°C)']) + 1), df_Sum_8['평균최고기온(°C)'], label='8월 평균최고기온', c='g')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()


plt.subplot(2, 2, 4)
plt.title('서울시 70~24년 여름철 평균최고기온 변화')
plt.plot(range(1, len(df_Sum_9['평균최고기온(°C)']) + 1), df_Sum_9['평균최고기온(°C)'], label='9월 평균최고기온', c='b')

plt.xlabel('여름(1970+x = 년도)')
plt.ylabel('기온')
plt.xlim(0,56)
plt.ylim(10, 50)
plt.legend()

plt.rcParams['figure.figsize'] = (12, 13)
plt.show()
