# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#plt.rcParams['font.family'] = 'gul_rim'
sys_fonts=fm.findSystemFonts()
print(sys_fonts)
# Out:
# ['C:\\Windows\\Fonts\\Candarali.ttf', 'C:\\Windows\\Fonts\\BOOKOSI.TTF', 'C:\\Windows\\Fonts\\BRUSHSCI.TTF', 'C:\\Windows\\Fonts\\STKAITI.TTF', 'C:\\Windows\\Fonts\\Hancom Gothic Bold.ttf', 'C:\\Windows\\Fonts\\ARIALNBI.TTF', 'C:\\Windows\\Fonts\\PLAYBILL.TTF', 'C:\\Windows\\Fonts\\corbelz.ttf', 'C:\\Windows\\Fonts\\trebucit.ttf', 'C:\\Windows\\Fonts\\PAPYRUS.TTF', 'C:\\Windows\\Fonts\\msjhbd.ttc', 'C:\\Windows\\Fonts\\trebucbd.ttf', 'C:\\Windows\\Fonts\\JUICE___.TTF', 'C:\\Windows\\Fonts\\SimsunExtG.ttf', 'C:\\Windows\\Fonts\\ENGR.TTF', 'C:\\Windows\\Fonts\\Candarai.ttf', 'C:\\Windows\\Fonts\\LTYPEO.TTF', 'C:\\Windows\\Fonts\\BRLNSB.TTF', 'C:\\Windows\\Fonts\\msgothic.ttc', 'C:\\Windows\\Fonts\\GOUDOSB.TTF', 'C:\\Windows\\Fonts\\malgunbd.ttf', 'C:\\Windows\\Fonts\\micross.ttf', 'C:\\Windows\\Fonts\\GOTHICB.TTF', 'C:\\Windows\\Fonts\\SCRIPTBL.TTF', 'C:\\Windows\\Fonts\\msyhbd.ttc', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\Windows\\Fonts\\FORTE.TTF', 'C:\\Windows\\Fonts\\CALIFI.TTF', 
# ...

# %%
import pandas as pd

df_ttf = pd.DataFrame(fm.fontManager.ttflist)
df_ttf
# Out:
#                                                  fname              name  \
# 0    C:\Users\plane\anaconda3\Lib\site-packages\mat...            cmtt10
# 1    C:\Users\plane\anaconda3\Lib\site-packages\mat...       DejaVu Sans
# 2    C:\Users\plane\anaconda3\Lib\site-packages\mat...      DejaVu Serif
# 3    C:\Users\plane\anaconda3\Lib\site-packages\mat...  DejaVu Sans Mono
# 4    C:\Users\plane\anaconda3\Lib\site-packages\mat...       STIXGeneral
# ..                                                 ...               ...
# 423                      C:\Windows\Fonts\msgothic.ttc         MS Gothic
# 424                   C:\Windows\Fonts\HANDotumExt.ttf     HCR Dotum Ext
# 425                        C:\Windows\Fonts\ARIALN.TTF             Arial
# 426                        C:\Windows\Fonts\LBRITE.TTF     Lucida Bright
# 427                        C:\Windows\Fonts\BROADW.TTF          Broadway
#
#        style variant  weight    stretch      size
# ...

# %%
plt.rcParams['font.family'] = 'gulim'

# %%
import numpy as np

np.random.seed(19680801)
fruit_weights = [
    np.random.normal(130, 10, size=100),
    np.random.normal(125, 20, size=100),
    np.random.normal(120, 30, size=100),
]
labels = ['복숭아', '오렌지', '토마토']
colors = ['peachpuff', 'orange', 'tomato']

fig, ax = plt.subplots()
ax.set_ylabel('fruit weight (g)')

bplot = ax.boxplot(fruit_weights,
                   patch_artist=True,  # fill with color
                   tick_labels=labels)  # will be used to label x-ticks

# fill with colors
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False #축의음수기호표시
plt.plot([-1, 2, 3, 4])
plt.title('대한민국')
plt.show()

# %%
year = [2014, 2017, 2020, 2023]
price = [25000, 31000, 53000, 63000]
plt.plot(year, price, 'rs:') #빨간색, 사각형마커, 점선
plt.axis([2013, 2024, 20000, 70000])
plt.show()

# %%
plt.plot(np.random.randn(10), 'k', label='one') #검은색실선
plt.plot(np.random.randn(10)*3, 'r--', label='two') #빨간색파선
plt.plot(np.random.randn(10)*10, 'g.', label='three') #선없이초록색점 마커로표시
plt.legend()
plt.show()

# %%
plt.subplot(2, 2, 1) # 2행2열중첫번째그래프
plt.plot(np.random.randn(10), 'b--')
plt.subplot(2, 2, 2) # 2행2열중두번째그래프
plt.plot(np.random.randn(100), 'r', alpha=0.7)
plt.subplot(2, 2, 3) # 2행2열중세번째그래프
plt.plot(np.random.randn(10), 'y^')
plt.subplot(2, 2, 4) # 2행2열중네번째그래프
plt.plot(np.random.randn(10), 'g.')
plt.show()
