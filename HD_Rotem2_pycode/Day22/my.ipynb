# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd

# %%
# 나눔글꼴 경로 설정
font_path = 'C:\\Windows\\Fonts\\gulim.ttc'

# 폰트 이름 가져오기
font_name = fm.FontProperties(fname=font_path).get_name()

# 폰트 설정
plt.rc('font', family=font_name)

# CSV 파일에서 데이터 불러오기
file_path = 'C:/Users/plane/Desktop/검거까지의 시간.csv'
df = pd.read_csv(file_path,encoding='utf-8')

# %%
# 데이터 정보 확인
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     object
#  1   2011        10 non-null     int64
#  2   2012        10 non-null     int64
#  3   2013        10 non-null     int64
#  4   2014        10 non-null     int64
#  5   2015        10 non-null     int64
#  6   2016        10 non-null     int64
#  7   2017        10 non-null     int64
#  8   2018        10 non-null     int64
#  9   2019        10 non-null     int64
#  10  2020        10 non-null     int64
#  11  2021        10 non-null     int64
#  12  2022        10 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 1.1+ KB
# None
#   Unnamed: 0  2011   2012   2013   2014   2015   2016   2017   2018   2019   \
# 0      1일 이내  10755   9350   9820   9755  10058  10279  11097   8721   7964
# 1      2일 이내    574    547    584    558    489    449    449    316    288
# 2      3일 이내    505    522    553    501    456    408    402    369    377
# 3     10일 이내   2409   2386   2673   2495   2572   2392   2398   2269   2166
# 4     1개월 이내   2835   2868   3462   3744   3985   4358   4853   5227   5671
# 5     3개월 이내   2428   2544   3135   3406   3334   3650   3922   4570   5163
# 6     6개월 이내   1077   1051   1410   1354   1320   1239   1156   1381   1472
# 7      1년 이내    746    704    958    914    964    841    780   1075    907
# 8      1년 초과   1096   1215   1342   1170   1195   1281   1277   1883   1499
# 9         미상      1      0      0      0      0      0      0      0      0
#
#    2020   2021   2022
# 0   5685   4553   4918
# 1    283    190    187
# 2    287    225    205
# 3   1909   1496   1566
# 4   5448   4719   4993
# 5   5776   6012   7067
# 6   1589   1606   2107
# 7    944    979   1029
# 8   1635   1514   1449
# 9      0      0      0

# %%
# 데이터 시각화
plt.figure(figsize=(14, 8))
# Iterate over each time slot and plot
for idx, row in df.iterrows():
    time_slot = row[0]
    values = row.iloc[1:].values
    plt.plot(df.columns[1:], values, marker='o',label=time_slot)
# Out:
# C:\Users\plane\AppData\Local\Temp\ipykernel_19208\2348317682.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   time_slot = row[0]
