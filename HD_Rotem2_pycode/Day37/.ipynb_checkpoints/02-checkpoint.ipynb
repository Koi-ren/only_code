# %%
import pandas as pd

df = pd.read_csv("./scaled_df_2023.csv")

# %%
print(df.shape)
# Out:
# (25, 27)

# %%
print(df)
# Out:
#     평균_지진옥외대피소_밀도  평균_자전거편의시설_밀도  평균_택시승차대_밀도  평균_작은도서관_밀도  평균_에코스쿨위치_밀도  \
# 0        0.547105       0.847404     0.045586    -1.473170     -0.139130
# 1       -0.808405       1.880422    -0.668297     0.791987     -0.260421
# 2       -0.953786      -0.602316    -0.516304    -0.604573     -0.614229
# 3        0.508313      -1.011901    -0.761546    -0.634175     -0.832547
# 4       -0.529504      -1.134715    -0.825090     0.575353     -0.552907
# 5       -0.859607       3.284968    -0.016070    -0.398373      0.044555
# 6       -0.158115      -0.840854    -0.362809     2.126270     -0.208041
# 7        0.146271      -1.060456     0.133562    -0.718642     -0.823592
# 8       -0.677198       0.189705    -0.458956    -0.876304      0.203015
# 9       -0.084521      -0.978918    -0.743180    -0.195428     -0.040556
# 10       1.205703       0.800740    -0.564796     0.903978      3.686478
# 11       0.482991      -0.625905    -0.377201     0.987592     -0.016370
# 12      -0.062064      -0.381917    -0.217641    -1.005768     -0.065770
# 13      -0.042551      -0.150128     0.150683    -0.239008     -0.407606
# 14      -1.655236       0.043720    -0.407549    -1.107950     -0.824632
# 15       1.707362      -0.707694    -0.468418    -0.274498     -0.618174
# 16      -0.458854       0.042037    -0.885375     0.830719     -0.714508
# 17      -0.136063       1.064332     0.190833    -0.153591     -0.545445
# 18       3.297338      -0.239623     1.382320     1.162925      2.154226
# 19       0.422396      -0.806318     0.525536     0.463089      0.097354
# 20      -0.099187       0.124941     0.622565    -1.282505      0.240874
# 21      -0.599970      -0.014511    -0.759812     1.922712     -0.554009
# 22      -1.334524      -0.063829     1.159485    -1.523500     -0.596187
# 23       0.599878      -0.474004     3.981526    -0.243935      1.328606
# 24      -0.457771       0.814820    -0.159053     0.966796      0.059015
#
#     평균_한파쉼터_밀도  평균_보행등_밀도  평균_CCTV_밀도  평균_불법주정차CCTV_밀도  평균_나눔카_밀도  ...  \
# 0    -0.630199  -0.659940    0.508896         0.879787   0.522481  ...
# 1     0.493574   0.620399   -0.230978        -0.850916   1.274388  ...
# 2     0.236263  -1.149218   -0.789743        -0.303606  -1.347587  ...
# 3    -0.292356  -0.066581   -1.213571        -1.197682  -0.237459  ...
# 4     0.504892  -1.463110    0.494142         0.166965  -0.589995  ...
# 5     0.808109  -0.369208    1.411765        -0.855826  -0.730345  ...
# 6    -0.933255   0.536211    0.649686         0.492371  -0.251749  ...
# 7     0.630116   0.707523    0.622691        -0.237164   0.719151  ...
# 8    -0.072889  -0.706037   -1.296846        -1.120167  -1.241245  ...
# 9    -0.086135  -0.673840   -1.359217        -0.803927  -1.767497  ...
# 10    0.723360   1.235565    0.842104         0.393435   0.618873  ...
# 11   -0.438909  -0.869775    0.133343        -1.555536   0.749877  ...
# 12   -1.072302   0.753238   -0.795746        -0.717507   1.669638  ...
# 13   -0.621662  -0.471394    1.048568        -0.175780   0.249368  ...
# 14   -0.775819  -1.300377   -0.752619         0.974025  -0.735060  ...
# 15   -0.116642  -0.341796    1.258492         1.430883  -0.443338  ...
# 5   3424.0    36.0   95.111111
# 6   3737.0    39.0   95.820513
# 7   2240.0    27.0   82.962963
# 8   3567.0    69.0   51.695652
# 9   1921.0    42.0   45.738095
# 10  2957.0    27.0  109.518519
# 11  2642.0    33.0   80.060606
# 12  3834.0    48.0   79.875000
# 13  2385.0    36.0   66.250000
# 14  4522.0    94.0   48.106383
# 15  2023.0    31.0   65.258065
# 16  2411.0    49.0   49.204082
# 17  5223.0    64.0   81.609375
# 18  3019.0    33.0   91.484848
# 19  4418.0    48.0   92.041667
# 20  3021.0    41.0   73.682927
# 21  3493.0    57.0   61.280702
# 22  2981.0    50.0   59.620000
# 23  3348.0    18.0  186.000000
# 24  3324.0    34.0   97.764706
#
# [25 rows x 27 columns]

# %%
df.head(3)
# Out:
#    평균_지진옥외대피소_밀도  평균_자전거편의시설_밀도  평균_택시승차대_밀도  평균_작은도서관_밀도  평균_에코스쿨위치_밀도  \
# 0       0.547105       0.847404     0.045586    -1.473170     -0.139130
# 1      -0.808405       1.880422    -0.668297     0.791987     -0.260421
# 2      -0.953786      -0.602316    -0.516304    -0.604573     -0.614229
#
#    평균_한파쉼터_밀도  평균_보행등_밀도  평균_CCTV_밀도  평균_불법주정차CCTV_밀도  평균_나눔카_밀도  ...  \
# 0   -0.630199  -0.659940    0.508896         0.879787   0.522481  ...
# 1    0.493574   0.620399   -0.230978        -0.850916   1.274388  ...
# 2    0.236263  -1.149218   -0.789743        -0.303606  -1.347587  ...
#
#        cctv     안내표지판      노면표기       보안등    서비스안내판   위치신고안내판     기타시설물  \
# 0  0.173342 -0.494228 -0.677263  0.114016 -0.222950 -0.114310 -0.198591
# 1 -0.833541 -0.672808  0.107947  0.030266 -0.222950 -0.229787 -0.609597
# 2  1.635693  2.345199  3.048038  1.490588 -0.141493  3.245619  0.577755
#
#    범죄발생정도  Grid개수   범죄발생정도평균
# 0  6763.0    78.0  86.705128
# 1  3398.0    50.0  67.960000
# 2  2497.0    45.0  55.488889
#
# [3 rows x 27 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_path = 'c:/WINDOWS/Fonts/GULIM.ttc'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

corr = df.corr()
plt.figure(figsize=(14,14))
sns.heatmap(corr, annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

cols_mean1 = ['평균_공공와이파이_밀도','평균_한파쉼터_밀도','평균_무더위쉼터_밀도']

scaler = StandardScaler()
df_cols_scaled1 = scaler.fit_transform(df[cols_mean1])
pca1 = PCA(n_components=1)
pca1.fit(df_cols_scaled1)
print('PCA 컴포넘트 별 변동성', pca1.explained_variance_ratio_)
# Out:
# PCA 컴포넘트 별 변동성 [0.79283719]

# %%
cols_mean2 = ['평균_따릉이대여소_밀도','평균_보행등_밀도']

df_cols_scaled2 = scaler.fit_transform(df[cols_mean2])
pca2 = PCA(n_components=1)
pca2.fit(df_cols_scaled2)
print('PCA 컴포넘트 별 변동성', pca2.explained_variance_ratio_)
# Out:
# PCA 컴포넘트 별 변동성 [0.84342083]

# %%
cols_mean3 = ['평균_공영주차장_밀도','평균_불법주정차CCTV_밀도']

df_cols_scaled3 = scaler.fit_transform(df[cols_mean3])
pca3 = PCA(n_components=1)
pca3.fit(df_cols_scaled3)
print('PCA 컴포넘트 별 변동성', pca3.explained_variance_ratio_)
# Out:
# PCA 컴포넘트 별 변동성 [0.78826298]

# %%
cols_mean4 = ['평균_CCTV_밀도','노면표기', '보안등','위치신고안내판']

df_cols_scaled4 = scaler.fit_transform(df[cols_mean4])
pca4 = PCA(n_components=1)
pca4.fit(df_cols_scaled4)
print('PCA 컴포넘트 별 변동성', pca3.explained_variance_ratio_)
# Out:
# PCA 컴포넘트 별 변동성 [0.78826298]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import statsmodels.api as sm

pca1_component = pca1.fit_transform(df_cols_scaled1)
pca2_component = pca1.fit_transform(df_cols_scaled2)
pca3_component = pca1.fit_transform(df_cols_scaled3)
pca4_component = pca1.fit_transform(df_cols_scaled4)

df['와이+무더위+한파'] = pca1_component
df['따릉이+보행등'] = pca2_component
df['공주_불주'] = pca3_component
df['안심시설물+CCTV'] = pca4_component

# 회귀 분석
X = df[['안심시설물+CCTV','와이+무더위+한파', '따릉이+보행등', '공주_불주','평균_지진옥외대피소_밀도','평균_자전거편의시설_밀도','평균_택시승차대_밀도','평균_작은도서관_밀도','평균_에코스쿨위치_밀도','평균_CCTV_밀도','평균_나눔카_밀도','평균_공중화장실_밀도','평균_공공아파트_밀도']]
y = df['범죄발생정도평균']

# sklearn을 이용한 회귀 분석
model = LinearRegression()
model.fit(X, y)

# 예측 결과
y_pred = model.predict(X)

# 평가 지표 계산
r2 = r2_score(y, y_pred)
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)

print(f'R^2: {r2}')
print(f'MSE: {mse}')
print(f'MAE: {mae}')

# statsmodels를 이용한 t-검정 유의수준 계산
X_with_const = sm.add_constant(X)  # 상수항 추가
sm_model = sm.OLS(y, X_with_const).fit()
print(sm_model.summary())
# Out:
# R^2: 0.8739646419507263
# MSE: 100.20252913687034
# MAE: 7.719218749936164
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               범죄발생정도평균   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     5.867
# Date:                Thu, 13 Feb 2025   Prob (F-statistic):            0.00294
# Time:                        18:55:06   Log-Likelihood:                -93.063
# No. Observations:                  25   AIC:                             214.1
# Df Residuals:                      11   BIC:                             231.2
# Df Model:                          13
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            78.3466      3.018     25.958      0.000      71.704      84.990
# 안심시설물+CCTV        0.7481      2.604      0.287      0.779      -4.984       6.480
# 와이+무더위+한파         1.5273      3.842      0.398      0.699      -6.928       9.983
# 따릉이+보행등           2.9414      5.612      0.524      0.611      -9.409      15.292
# 공주_불주            -0.9363      5.081     -0.184      0.857     -12.119      10.247
# 평균_지진옥외대피소_밀도    -8.7323      6.034     -1.447      0.176     -22.012       4.548
# 평균_자전거편의시설_밀도    -3.5517      5.148     -0.690      0.505     -14.883       7.780
# 평균_택시승차대_밀도      11.9810      6.233      1.922      0.081      -1.738      25.700
# 평균_작은도서관_밀도      -0.5673      5.101     -0.111      0.913     -11.795      10.660
# 평균_에코스쿨위치_밀도      5.9037      5.488      1.076      0.305      -6.176      17.984
# 평균_CCTV_밀도        8.9166      5.926      1.505      0.161      -4.126      21.959
# 평균_나눔카_밀도         6.5227      4.296      1.518      0.157      -2.933      15.978
# 평균_공중화장실_밀도       2.2750      5.603      0.406      0.693     -10.058      14.608
# 평균_공공아파트_밀도       3.2522      5.646      0.576      0.576      -9.174      15.678
# ==============================================================================
# Omnibus:                        0.062   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.970   Jarque-Bera (JB):                0.275
# Skew:                           0.050   Prob(JB):                        0.871
# Kurtosis:                       2.496   Cond. No.                         8.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
