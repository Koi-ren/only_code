# %%
# !pip install networkx

# %%
import pandas as pd
import matplotlib.pyplot as plt

UA = pd.read_csv('C:/ws/HD_Rotem2_pycode/Day10/우크라이나.csv', encoding = 'cp949')
UA.head(3)
# Out:
#          뉴스 식별자        일자   언론사          기고자  \
# 0  4.100078e+06  20241230   뉴스핌          이나영
# 1  2.100311e+06  20241230  서울경제  워싱턴=이태규 특파원
# 2  2.100351e+06  20241230  이투데이          김나은
#
#                                           제목     통합 분류1     통합 분류2     통합 분류3  \
# 0  소니드-소니드에이아이, 우크라이나 재건 겨냥 'AI 전방 경계시스템' 개발  IT_과학>모바일   IT_과학>보안        NaN
# 1                  트럼프 취임 앞두고 美 하원의장 공백 재연되나   국제>미국_북미     국제>중남미   국제>유럽_EU
# 2               세계 각국 정상, 카터 전 미국 대통령 별세에 애도     정치>청와대   국제>미국_북미     국제>중남미
#
#   사건/사고 분류1 사건/사고 분류2 사건/사고 분류3  \
# 0       NaN       NaN       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       NaN
#
#                                                   인물  \
# 0                                                NaN
# 1   트럼프,전,토머스,마이크 존슨,케빈 매카시,제임스 코머,스콧,존슨,도널드 트럼프,매카시
# 2  에마뉘엘 마크롱,조 바이든,스타머,데이비드,키어,부시,쥐스탱 트뤼도,빌 클린턴,바이...
#
#                                                 위치  \
# 0                                    우크라이나,전방,우범지역
# ...

# %%
UA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   뉴스 식별자             20000 non-null  float64
#  1   일자                 20000 non-null  int64
#  2   언론사                20000 non-null  object
#  3   기고자                18962 non-null  object
#  4   제목                 20000 non-null  object
#  5   통합 분류1             20000 non-null  object
#  6   통합 분류2             19090 non-null  object
#  7   통합 분류3             17313 non-null  object
#  8   사건/사고 분류1          4331 non-null   object
#  9   사건/사고 분류2          858 non-null    object
#  10  사건/사고 분류3          231 non-null    object
#  11  인물                 17577 non-null  object
#  12  위치                 19992 non-null  object
#  13  기관                 19966 non-null  object
#  14  키워드                20000 non-null  object
#  15  특성추출(가중치순 상위 50개)  20000 non-null  object
# ...

# %%
UA.iloc[:, [4]]
# Out:
#                                                제목
# 0       소니드-소니드에이아이, 우크라이나 재건 겨냥 'AI 전방 경계시스템' 개발
# 1                       트럼프 취임 앞두고 美 하원의장 공백 재연되나
# 2                    세계 각국 정상, 카터 전 미국 대통령 별세에 애도
# 3           소니드 소니드에이아이, 우크라 재건 겨냥 AI 전방 경계시스템 개발
# 4             [신년사] 정태순 해운협회 회장 "불확실성에 도전정신으로 극복"
# ...                                           ...
# 19995          북러 위험한 결속에 한미일 경고했지만 ‘연내 정상회의’ 미지수
# 19996                     尹 “러 북 밀착 결코 좌시하지 않을 것”
# 19997   치솟는 원자재값 예타에 ‘발목’ 9개 노선 중 7곳 착공 못해 [심층기획]
# 19998  사실로 드러난 북한군 러시아 파병설, 지정학적 융합 가속화되나? [fn기고]
# 19999           美 대선 D-15...우리 기업 최대 관심은 '수출입 관세'
#
# [20000 rows x 1 columns]

# %%
df = UA.iloc[:, [4]]
print(df)
# Out:
#                                                제목
# 0       소니드-소니드에이아이, 우크라이나 재건 겨냥 'AI 전방 경계시스템' 개발
# 1                       트럼프 취임 앞두고 美 하원의장 공백 재연되나
# 2                    세계 각국 정상, 카터 전 미국 대통령 별세에 애도
# 3           소니드 소니드에이아이, 우크라 재건 겨냥 AI 전방 경계시스템 개발
# 4             [신년사] 정태순 해운협회 회장 "불확실성에 도전정신으로 극복"
# ...                                           ...
# 19995          북러 위험한 결속에 한미일 경고했지만 ‘연내 정상회의’ 미지수
# 19996                     尹 “러 북 밀착 결코 좌시하지 않을 것”
# 19997   치솟는 원자재값 예타에 ‘발목’ 9개 노선 중 7곳 착공 못해 [심층기획]
# 19998  사실로 드러난 북한군 러시아 파병설, 지정학적 융합 가속화되나? [fn기고]
# 19999           美 대선 D-15...우리 기업 최대 관심은 '수출입 관세'
#
# [20000 rows x 1 columns]

# %%
from konlpy.tag import Okt

okt = Okt()
nouns = okt.nouns()
nouns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 from konlpy.tag import Okt
#       3 okt = Okt()
# ----> 4 nouns = okt.nouns(srt(df))
#       5 nouns
#
# NameError: name 'srt' is not defined
