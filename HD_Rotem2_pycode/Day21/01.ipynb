# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_0 = pd.read_csv("c:/Users/plane/Desktop/everything/현대로템 AI 개발자 교육/1차 프로젝트/수집데이터/시각화자료데이터/수사단서/범죄의_수사단서_2022.csv")
data_1 = pd.read_csv("c:/Users/plane/Desktop/everything/현대로템 AI 개발자 교육/1차 프로젝트/수집데이터/시각화자료데이터/수사단서/범죄의_수사단서_2021.csv")
data_2 = 
data_3 = 
data_4 = 
data_5 = 
data_6 = 
data_7 = 
data_8 = 
data_9 = 
data_10 = 
data_11 = 
data_12 =

# %%
data_0
# Out:
#     죄종별(1)       죄종별(2)     2022 2022.1   2022.2  2022.3  2022.4 2022.5  \
# 0   죄종별(1)       죄종별(2)        계    현행범       신고      신고      신고     신고
# 1   죄종별(1)       죄종별(2)       소계     소계       소계   피해자신고      고소     고발
# 2        계           소계  1482433  72630  1216044  545914  271626  52591
# 3     강력범죄           소계    24954   2569    21710    9557    8438    103
# 4     강력범죄         살인기수      275     47      154      16      17      5
# 5     강력범죄        살인미수등      427    208      202      59      61      2
# 6     강력범죄           강도      516     90      398     290      59      -
# 7     강력범죄           강간     5467    286     4937    1521    2591     25
# 8     강력범죄         유사강간      947     50      870     287     440      6
# 9     강력범죄         강제추행    15864   1457    14167    6873    5148     62
# 10    강력범죄  기타 강간·강제추행등      225     15      200      68      93      -
# 11    강력범죄           방화     1233    416      782     443      29      3
# ...

# %%
data_1
# Out:
#     죄종별(1)       죄종별(2)     2021 2021.1   2021.2  2021.3  2021.4 2021.5  \
# 0   죄종별(1)       죄종별(2)        계    현행범       신고      신고      신고     신고
# 1   죄종별(1)       죄종별(2)       소계     소계       소계   피해자신고      고소     고발
# 2        계           소계  1429826  64875  1162173  568384  237353  44991
# 3     강력범죄           소계    22476   2268    19536    8170    8217    115
# 4     강력범죄         살인기수      270     50      136      17      29      1
# 5     강력범죄        살인미수등      388    182      192      60      48      2
# 6     강력범죄           강도      495     87      353     244      58      1
# 7     강력범죄           강간     5263    275     4794    1469    2610     30
# 8     강력범죄         유사강간      814     57      730     231     390      3
# 9     강력범죄         강제추행    13962   1256    12449    5681    4991     75
# 10    강력범죄  기타 강간·강제추행등      238     24      204      84      79      1
# 11    강력범죄           방화     1046    337      678     384      12      2
# ...
