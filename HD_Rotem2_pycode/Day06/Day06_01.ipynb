# %%
# !pip install openpyxl

# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('C:/ws/HD_Rotem2_pycode/data_study_01/03장/characters.xlsx')
wb.sheetnames
# Out:
# ['Sheet1']

# %%
sheet1 = wb['Sheet1']

# %%
sheet1['D3']
# Out:
# <Cell 'Sheet1'.D3>

# %%
#wb2 = openpyxl.Workbook()
wb.create_sheet('Sheet2222')
print(wb.sheetnames)
# Out:
# ['Sheet1', 'Sheet2222', 'Sheet22221', 'Sheet22222', 'Sheet22223']

# %%
wb.save('C:/ws/HD_Rotem2_pycode/data_study_01/03장/characters_new.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 wb.save('C:/ws/HD_Rotem2_pycode/data_study_01/03장/characters_new.xlsx')
#
# File ~\anaconda3\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~\anaconda3\Lib\site-packages\openpyxl\writer\excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
# ...

# %% [markdown]
# data1, data2, data3
# -> traffice_new.xlsx
# -> 하나의 엑셀파일로 로딩해서 sheet1, sheet2, shtte3에 각각 매핑하여 저장되도록

# %%
wb = openpyxl.load_workbook('C:/ws/HD_Rotem2_pycode/data_study_01/03장/traffic.xlsx')

# %%
print(wb.sheetnames)
# Out:
# ['경기도 의정부시_의정부경전철 혼잡도', '대전교통공사_열차 혼잡도 분석', '서울특별시_지하철 혼잡도 정보']

# %%
wb.create_sheet('data1')
# Out:
# <Worksheet "data1">

# %%
wb.create_sheet('data2')
wb.create_sheet('data3')
# Out:
# <Worksheet "data3">

# %%
wb.sheetnames
# Out:
# ['경기도 의정부시_의정부경전철 혼잡도',
#  '대전교통공사_열차 혼잡도 분석',
#  '서울특별시_지하철 혼잡도 정보',
#  'data1',
#  'data2',
#  'data3']

# %%
wb.save('C:/ws/HD_Rotem2_pycode/data_study_01/03장/traffic_new.xlsx')

# %%
wb = openpyxl.Workbook()

# %%
ws = wb.active

# %%
import csv

with open('C:/ws/HD_Rotem2_pycode/data_study_01/03장/data1.csv', encoding = 'cp949') as f:
    reader = csv.reader(f)
    for row in reader:
        ws.append(row)

# %%
wb.create_sheet('ws2')
# Out:
# <Worksheet "ws2">

# %%
ws2 = wb.active
with open('C:/ws/HD_Rotem2_pycode/data_study_01/03장/data2.csv', encoding = 'cp949') as f:
    reader = csv.reader(f)
    for row in reader:
        ws2.append(row)

# %%
wb.create_sheet('ws3')
# Out:
# <Worksheet "ws3">

# %%
ws3 = wb.active
with open('C:/ws/HD_Rotem2_pycode/data_study_01/03장/data2.csv', encoding = 'cp949') as f:
    reader = csv.reader(f)
    for row in reader:
        ws3.append(row)

# %%
ws.title = '경기도 의정부시_의정부겅전철 혼잡도'
ws2.title = '대전교통공사_열차 혼잡도 분석'
ws3.title = '서울특별시_지하철 혼잡도 정보'

wb.save('C:/ws/HD_Rotem2_pycode/data_study_01/03장/traffic_new.xlsx')

# %%
import requests
from bs4 import BeautifulSoup

# 1. URL 요청
url = "https://finance.naver.com/item/main.nhn?code=005930" # 삼성전자 주식 페이지
response = requests.get(url)

# 2. HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 3. 데이터 추출
price = soup.select_one(".no_today .blind").text

# 4. 결과 출력
print(f"삼성전자 현재 주가: {price}원")
# Out:
# 삼성전자 현재 주가: 53,500원

# %%
import requests
from bs4 import BeautifulSoup

# 1. URL 요청
url = "https://finance.naver.com/item/main.nhn?code=005930" # 삼성전자 주식 페이지
response = requests.get(url)

# 2. HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

headers = soup.find_all("")
for header in headers:
    print(header.texxt)
# Out:
# None
# None
# None
# None
