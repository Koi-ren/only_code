# %%
import os; os.environ["NPU_COMPLETION_CYCLES"] = "0"

# %%
import glob
from itertools import islice
import time

import furiosa.runtime.session
from furiosa.optimizer import optimize_model
from furiosa.quantizer import quantize, Calibrator, CalibrationMethod

import cv2
import numpy as np
import onnx
import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 from itertools import islice
#       3 import time
# ----> 5 import furiosa.runtime.session
#       6 from furiosa.optimizer import optimize_model
#       7 from furiosa.quantizer import quantize, Calibrator, CalibrationMethod
#
# ModuleNotFoundError: No module named 'furiosa'

# %%
import fu
